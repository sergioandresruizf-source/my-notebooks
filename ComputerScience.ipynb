# %% [markdown]
# ---
#
# # Jupyter Notebook Algorithms Sections
#
# ---

# %% [markdown]
# ## Euclidean Algorithm
# ---

# %%
def euclidean_gcd(a: int, b: int) -> int:
    """
    This function implements the euclidean algorithms
    to get the greater common divisor of two numbers

    Args:
        a(int): First number in the algorithm. Expected to be greater than the other
        b(int): Second number in the algorithm.
    
    Returns:
        int: The greater common divisor of the two numbers
    """
    if b>a:
        a, b = b, a
    while b!= 0:
        r = a%b
        a = b
        b = r
    return a

print(euclidean_gcd(36, 54))
# Out:
# 18

# %%
resultado = euclidean_gcd(24, 60)

# %% [markdown]
# ## Babylonean Square Root Method

# %%
def square_root_babylonean_method(s: int) -> float:
    """
    This function implements the babylonean method to get the approximate square root of a number.

    Args: 
        s(int): Input number to calculate the square root.
        
    Returns:
        A decimal number that is the approximate square root of the input number.
    """
    x_n = s/2
    diff = 0.0001
    x_n_1 = (1/2)*(x_n + s/x_n)
    while abs(x_n_1 - x_n) > diff:
        x_n = x_n_1
        x_n_1 = (1/2)*(x_n + s/x_n)
    return x_n_1

# %%
resultado = square_root_babylonean_method(25)
print(resultado)
resultado_1= euclidean_gcd(24, 60)
print(resultado_1 + resultado)
# Out:
# 5.000000000016778
# 17.000000000016776

# %% [markdown]
# >metodos numéricos

# %% [markdown]
# # Maximum element in an array
# ---

# %%
def maximum_array(array: list) -> int:
    """
    This function gets the maximum value into a given array.

    Args:
        array(list): Array of numbers

    Returns:
        An integer number with the maximum in the array. If array is empty,
        a "None" value will be returned.
    """
    if len(array) > 0:
        max = array[0]
        for number in array:
            if number > max:
                max = number    
    else:
        #array is empty
        max = None

    return max     #Tener un solo valor por funcion, no en cada condicional

# %%
arreglo = [1, 2, 3, -3, 99]
print(maximum_array(arreglo))
# Out:
# 99

# %%
# Mathematical Notation

---
Mathematical notatiion provides a normal way to express *algorithms* using
symbols, formulas, etc

* Precision: Unambiguous specification
* Universality: Language independent
* Conciseness: Compact representation
* Analysis: Enables formal verification
  
## Set operations

>Set operations in mathematical notation makes programming easier

>Is better use an example, understand the problem and make the algorithm

* S={x is N: x is prime and x<20}
* ∀x is S, P(x) (for all elements in S, property P holds)
* Exists some x is S
```python
def is_prime(n):
    .
    .
    .
    s=[]
    for x in range(1,20):
        if is_prime(x): 
            s.add(x)

```
# Out:
# 99

# %% [markdown]
# # Mathematical Notation
#
# ---
# Mathematical notatiion provides a normal way to express *algorithms* using
# symbols, formulas, etc
#
# * Precision: Unambiguous specification
# * Universality: Language independent
# * Conciseness: Compact representation
# * Analysis: Enables formal verification
#
# ## Set operations
#
# >Set operations in mathematical notation makes programming easier
#
# >Is better use an example, understand the problem and make the algorithm
#
# * S={x is N: x is prime and x<20}
# * ∀x is S, P(x) (for all elements in S, property P holds)
# * Exists some x is S
# ```python
# def is_prime(n):
#     .
#     .
#     .
#     s=[]
#     for x in range(1,20):
#         if is_prime(x):
#             s.add(x)
#
# ```

# %% [markdown]
# # Algorithms of daily life
# ---
#
# 1. Organize the backpack for university
#    """
#    This algorith is a daily task I do
#     Input:
#
#         Full backpack
#
#     Output:
#
#         backpack ready to go """
#    * Open the backpack
#    * Take out the books that i won't need the next day
#    * Put into the snacks, phone charger, books, etc
#    * Close the backpack
#
# 2. Select the daily outfit
#     Input
#         A closet full of clothes
#     Output
#         An outfit defined for an especific day
#
#     * Analize the weather
#     * Open the closet
#     * Take a pair of socks
#     * Take underweaar
#     * Take a pair of pants
#     * If is necesary, take a belt
#     * Take a shirt
#     * If is necesary, take a jacket
#     * Take a pair of shoes
#     * Close the closet
#     * Put on clothes

# %% [markdown]
# # Funtions

# %% [markdown]
# ## Markdown Fuctions
# This is a __notebook__ for the *course* just with Python
# ### List
# - Greedy
# - Backtracking
# - Search and Sort
#     * Más encabezados con tabulaciones
# ___
# #### Video
# [youtube.com](https://www.youtube.com/watch?v=oxaH9CFpeEE&t=1002s)
#
# [VideoClass](https://www.youtube.com/watch?v=oxaH9CFpeEE&t=1002s "Youtube")
#
# ---
# 1. When you use the notation of a programming language is necesary to use 'backtick'(Tilde Invertida)
# 2. It's useful for show a code without run it.
# ##### Python
# ```python
# def example(a,b):
#     return a+b
# ```
# ##### html
# ```html
# <h1>This is a HTML example</h1>
# ```
# ---
# > This is a quote
# #### Data Table
#
# |Precio     |Cantidad   |Total      |
# |-----------|-----------|-----------|
# |1000       |2          |2000       |
#
# <!-- GITHUB MARKDOWN -->
# * [x] Task 1
# * [ ] Task 2
# * [ ] Task 3
# * [x] Task 4
